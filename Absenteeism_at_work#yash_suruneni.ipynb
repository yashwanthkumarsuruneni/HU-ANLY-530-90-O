# %% [markdown]
# # Final Project - Absenteeism at work

# %% [markdown]
# ### Data Exploration

# %%
import pandas as pd
input_file = "./Absenteeism_at_work_train.csv"
absent_records = pd.read_csv(input_file)
absent_records.head(5)
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time Age  \
# 0                     289                               36            13  33
# 1                     118                               13            18  50
# 2                     179                               51            18  38
# 3                     279                                5            14  39
# 4                     289                               36            13  33
#
#   Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
absent_records.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 666 entries, 0 to 665
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               666 non-null    int64
#  1   Reason for absence               666 non-null    int64
#  2   Month of absence                 666 non-null    int64
#  3   Day of the week                  666 non-null    int64
#  4   Seasons                          666 non-null    int64
#  5   Transportation expense           666 non-null    int64
#  6   Distance from Residence to Work  666 non-null    int64
#  7   Service time                     666 non-null    int64
#  8   Age                              666 non-null    object
#  9   Work load Average/day            666 non-null    object
#  10  Hit target                       665 non-null    float64
#  11  Disciplinary failure             666 non-null    int64
# ...

# %%
absent_records.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         1
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             2
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
absent_records = pd.DataFrame(data = absent_records).dropna()
absent_records.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %% [markdown]
# There are about 20 Features and the target variable which is `Absenteeism time in hours`

# %%
absent_records.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
import seaborn as sea
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
sea.set_context(context='paper')
sea.heatmap(absent_records.corr(), fmt='.2f', annot=True)
absent_records.corr()
# Out:
#                                        ID  Reason for absence  \
# ID                               1.000000           -0.063342
# Reason for absence              -0.063342            1.000000
# Month of absence                 0.013896           -0.114313
# Day of the week                  0.016960            0.099091
# Seasons                          0.089268           -0.136712
# Transportation expense          -0.191275           -0.139842
# Distance from Residence to Work -0.494675            0.164176
# Service time                    -0.315007            0.076614
# Hit target                       0.000133            0.122590
# Disciplinary failure             0.007398           -0.559613
# Education                       -0.065212           -0.085045
# Son                              0.035916           -0.044514
# Social drinker                  -0.467151            0.060161
# Social smoker                   -0.001073           -0.103483
# ...

# %%
absent_records.drop(['Month of absence','Day of the week','Seasons','Weight','Height','Hit target'], 1, inplace = True)

# %%
absent_records['Age Group'] = ['young employee' if 25<=age<=35 else 'mid age employee' if 36<=age<=45 else 'old employee' if age>=45 else None\
                      for age in list(absent_records['Age'].replace("R", 0).astype('int64').values)  ] 

absent_records['smoke_cat'] = ['no' if period<=0 else 'yes' if period >=1 else None \
                               for period in list (absent_records['Social smoker'].values)]

absent_records['Disciplinary action'] = ['not taken' if period<=0 else 'taken' if period >=1 else None \
                               for period in list (absent_records['Disciplinary failure'].values)]

absent_records['drink_cat'] = ['no' if period<=0 else 'yes' if period >=1 else None \
                               for period in list (absent_records['Social drinker'].values)]

absent_records['Education_level'] = ['high school' if  period ==1 else 'graduate' if  period ==2 else "postgraduate" if  period ==3 else 'doctor' if  period ==4 else  None \
                               for period in list (absent_records['Education'].values)]

absent_records['Transportation costs'] = ['cheap' if 100<=fare<=200 else 'expensive' if 200<=fare<=300 else 'very expensive' if fare>300 else None \
                                   for fare in list(absent_records["Transportation expense"].values)]

absent_records['distance'] = ['close' if 0<=dist<=15 else 'far' if 15<=dist<=35 else 'very far' if dist>35 else None \
                                   for dist in list(absent_records["Distance from Residence to Work"].values)]

absent_records['absenteeism category'] = ['group_0' if period==0 else 'group_1' if 0 <=period<=6 else 'group_2' if period>=6 else None \
                               for period in list (absent_records["Absenteeism time in hours"].values)]

# %%
# Influence of age 

plt.bar(absent_records['Age Group'].astype('str'), absent_records['Absenteeism time in hours'])
plt.ylabel("Numbers of hours Absent")
plt.xlabel("Age Group")
plt.show()

# Influence of Smoking

plt.bar(absent_records['smoke_cat'], absent_records['Absenteeism time in hours']) 
plt.xlabel('Social smoker')
plt.ylabel("hours absent")
plt.show()

# Infuence of social drinking habit

plt.bar(absent_records['drink_cat'], absent_records['Absenteeism time in hours']) 
plt.xlabel('Social drinker')
plt.ylabel("hours absent")
plt.show()

# Influence of Education level

plt.bar(absent_records['Education_level'], absent_records['Absenteeism time in hours']) 
plt.xlabel('Education level')
plt.ylabel("hours absent")
plt.show()


# Transportation Costs

plt.bar(absent_records['Transportation costs'].astype('str'), absent_records['Absenteeism time in hours']) 
plt.xlabel('Transportation costs')
plt.ylabel("hours absent")
plt.show()

# Distance Costs 

plt.bar(absent_records['distance'].astype('str'), absent_records['Absenteeism time in hours']) 
plt.xlabel('Distance to work')
plt.ylabel("hours absent")
plt.show()

# %%
# Categorizing absent times 

plt.figure(figsize=(8,6))
sea.countplot(x='absenteeism category',data=absent_records)
# Out:
# <AxesSubplot:xlabel='absenteeism category', ylabel='count'>

# %%
# Categorizing absentism into groups

import seaborn as sea
import warnings
warnings.filterwarnings("ignore")

sea.factorplot(data=absent_records, x='Reason for absence', kind= 'count',size=4,aspect=2)

# %% [markdown]
# ##  TASK-1 Mandatory

# %%
absent_records.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         1
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             2
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
absent_records = pd.DataFrame(data = absent_records).dropna()

absent_records.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
# dividing into groups

import warnings
warnings.filterwarnings("ignore")
import numpy as np

group_0 = absent_records['Absenteeism time in hours'] == 0
x = absent_records['Absenteeism time in hours'] > 0
y = absent_records['Absenteeism time in hours'] <= 6 
group_1 = np.logical_and(x, y)
group_2 = absent_records['Absenteeism time in hours'] > 6

absent_records.loc[group_0,'Absenteeism time in hours'] = 0
absent_records.loc[group_1,'Absenteeism time in hours'] = 1
absent_records.loc[group_2,'Absenteeism time in hours'] = 2

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
hrs_label = pd.Series(label_encoder.fit_transform(absent_records['Absenteeism time in hours']>6))

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import cross_val_score
from sklearn import metrics

absent_records['Age'] = absent_records['Age'].replace("R", 0).astype('int64')
X_pd = pd.DataFrame(data = absent_records['Work load Average/day ']) 
X_replace = X_pd.replace(',','', regex=True)
X_np = X_replace.values
X_fa = X_np.astype('float64')
absent_records["Work load Average/day "] = X_fa


y = absent_records['Absenteeism time in hours']
X = absent_records.drop(['Absenteeism time in hours','Weight'],axis=1)

# split dataset to 70-30 training and testing resp.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25 ,random_state=52)

#Shape of  training and test datasets
print(X_train.shape)
print(y_train.shape)
# Out:
# (497, 19)
# (497,)

# %%
from sklearn import tree 
from sklearn.tree import DecisionTreeClassifier 
model = tree.DecisionTreeClassifier() 
model = model.fit(X_train, y_train)

# %%
# Evaluating model performance 

from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score
import seaborn as sea
import matplotlib.pyplot as plt

y_predict = model.predict(X_test)

def conftable(test,pred, imagename):
    confmatrix= confusion_matrix(y_test, y_predict)
    plt.matshow(confmatrix)
    plt.title('Confusion matrix')
    plt.colorbar()
    plt.ylabel('Truth')
    plt.xlabel('Predicted')
    plt.savefig(imagename)
    plt.show()
    print(confmatrix)
conftable(y_test,y_predict,"conf")

print(accuracy_score(y_test, y_predict)*100)
# Out:
# [[ 9  0  0]
#  [ 1 73 18]
#  [ 0 21 44]]
# 75.90361445783132

# %%
from sklearn.tree import export_graphviz 
from graphviz import Source

export_graphviz(model, out_file ='tree.dot', feature_names =X.columns)
 
dot_data = tree.export_graphviz(model, out_file=None,feature_names=X.columns, filled=True, rounded=True, special_characters=True) 
graph = Source(dot_data) 
graph

# %% [markdown]
# ## Random Forest Classifiers

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=123)
clf = RandomForestClassifier()
clf.fit(X_train,y_train)
y_predict = clf.predict(X_test)

def conftable(test,pred, imagename):
    confmatrix= confusion_matrix(y_test, y_predict)
    plt.matshow(confmatrix)
    plt.title('Confusion matrix')
    plt.colorbar()
    plt.ylabel('Truth')
    plt.xlabel('Predicted')
    plt.savefig(imagename)
    plt.show()
    print(confmatrix)
conftable(y_test,y_predict,"conf")

print(accuracy_score(y_test,y_predict)*100)
# Out:
# [[ 7  1  0]
#  [ 0 69 10]
#  [ 0  9 37]]
# 84.9624060150376

# %%
import pandas as pd 
feature_importances = pd.DataFrame(clf.feature_importances_,index = X_train.columns,
columns=['importance']).sort_values('importance',ascending=False)
feature_importances
# Out:
#                                  importance
# Reason for absence                 0.350020
# Disciplinary failure               0.086863
# Work load Average/day              0.069733
# Day of the week                    0.060530
# Hit target                         0.057764
# Month of absence                   0.056397
# Transportation expense             0.050826
# ID                                 0.046178
# Age                                0.032090
# Service time                       0.030091
# Seasons                            0.028175
# Height                             0.026875
# Distance from Residence to Work    0.026502
# Body mass index                    0.025859
# Son                                0.021962
# Pet                                0.012534
# Social drinker                     0.007577
# Education                          0.005285
# Social smoker                      0.004738

# %%
# Correlation
np.corrcoef(y_test,y_predict)
# Out:
# array([[1.        , 0.76544371],
#        [0.76544371, 1.        ]])

# %%
#RMSE
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = sqrt(mean_squared_error(y_test,y_predict))

print(rmse)
# Out:
# 0.38778336716474066

# %% [markdown]
# ## Naive Bayes

# %%
# Fitting Naive Bayes to the Training set
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb = gnb.fit(X_train, y_train)
y_predict = gnb.fit(X_train, y_train).predict(X_test)

# %%
# Evaluating the model performance and calculating accuracy

from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score

def conftable(test,pred, imagename):
    confmatrix= confusion_matrix(y_test, y_predict)
    plt.matshow(confmatrix)
    plt.title('Confusion matrix')
    plt.colorbar()
    plt.ylabel('Truth')
    plt.xlabel('Predicted')
    plt.savefig(imagename)
    plt.show()
    print(confmatrix)
conftable(y_test,y_predict,"conf")

print("Accuracy Score is")
print(accuracy_score(y_test, y_predict)*100)
# Out:
# [[ 7  1  0]
#  [ 0 62 17]
#  [ 3 14 29]]
# Accuracy Score is
# 73.68421052631578

# %%
#RMSE
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = sqrt(mean_squared_error(y_test,y_predict))

print(rmse)
# Out:
# 0.5751756841776023

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression(random_state = 0)
logmodel.fit(X_train, y_train)
y_predict = logmodel.predict(X_test)

# %%
def conftable(test,pred, imagename):
    confmatrix= confusion_matrix(y_test, y_predict)
    plt.matshow(confmatrix)
    plt.title('Confusion matrix')
    plt.colorbar()
    plt.ylabel('Truth')
    plt.xlabel('Predicted')
    plt.savefig(imagename)
    plt.show()
    print(confmatrix)
conftable(y_test,y_predict,"conf")

print(accuracy_score(y_test,y_predict)*100)
# Out:
# [[ 0  1  7]
#  [ 0 68 11]
#  [ 0 18 28]]
# 72.18045112781954

# %% [markdown]
# ## SUPPORT VECTOR MACHINE

# %%
from sklearn import svm
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1,1)).fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

clf = svm.SVC(kernel='linear')
#clf = svm.LinearSVC(C=1)
clf.fit(X_train, y_train)
y_predict = clf.predict(X_test)



def conftable(test,pred, imagename):
    confmatrix= confusion_matrix(y_test, y_predict)
    plt.matshow(confmatrix)
    plt.title('Confusion matrix')
    plt.colorbar()
    plt.ylabel('Truth')
    plt.xlabel('Predicted')
    plt.savefig(imagename)
    plt.show()
    print(confmatrix)
conftable(y_test,y_predict,"conf")


print(accuracy_score(y_test, y_predict)*100)
# Out:
# [[ 7  1  0]
#  [ 0 70  9]
#  [ 0 11 35]]
# 84.21052631578947

# %%
# Polynomial kernel 

from sklearn import svm
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
# Design the model

scaler = MinMaxScaler(feature_range=(-1,1)).fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

clf = svm.SVC(kernel='poly')
#clf = svm.LinearSVC(C=1)
clf.fit(X_train, y_train)
y_predict = clf.predict(X_test)


def conftable(test,pred, imagename):
    confmatrix= confusion_matrix(y_test, y_predict)
    plt.matshow(confmatrix)
    plt.title('Confusion matrix')
    plt.colorbar()
    plt.ylabel('Truth')
    plt.xlabel('Predicted')
    plt.savefig(imagename)
    plt.show()
    print(confmatrix)
conftable(y_test,y_predict,"conf")

print(accuracy_score(y_test, y_predict)*100)
# Out:
# [[ 7  1  0]
#  [ 0 67 12]
#  [ 0 15 31]]
# 78.94736842105263

# %%
# RBF kernel 
from sklearn import svm
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score

clf = svm.SVC(kernel='rbf')
#clf = svm.LinearSVC(C=1)
clf.fit(X_train, y_train)
y_predict = clf.predict(X_test)

def conftable(test,pred, imagename):
    confmatrix= confusion_matrix(y_test, y_predict)
    plt.matshow(confmatrix)
    plt.title('Confusion matrix')
    plt.colorbar()
    plt.ylabel('Truth')
    plt.xlabel('Predicted')
    plt.savefig(imagename)
    plt.show()
    print(confmatrix)
conftable(y_test,y_predict,"conf")

print(accuracy_score(y_test, y_predict)*100)
# Out:
# [[ 7  1  0]
#  [ 0 70  9]
#  [ 0 13 33]]
# 82.70676691729322
